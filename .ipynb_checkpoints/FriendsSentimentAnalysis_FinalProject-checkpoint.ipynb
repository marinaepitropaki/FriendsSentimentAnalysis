# %%
import pandas as pd
import glob
import os
import re

# %%
# remove later
marinas_path = '/Users/mep/Desktop/mep/SocialGraphs/FriendsSentimentAnalysis/episodes'

# %%
# remove later
# stella add your path here!!
stellas_path = ''

# %%
# change according to who's working
episodes_path = marinas_path

list_of_episodes = os.listdir(episodes_path)
print(list_of_episodes)
# Out:
# ['S01E01 Monica Gets A Roommate.txt', 'S01E02 The Sonogram At The End.txt']

# %%
#input each apisode into a list of str 
text_file = open(episodes_path+"/"+list_of_episodes[0], "r")
episode_script = text_file.read()
text_file.close()
scenes_of_episode = re.split(r'\[Scene:',episode_script)

# %%
# just to check
for scene in range(len(scenes_of_episode)):
    print(scenes_of_episode[scene]+'\n')
# Out:
# The One Where Monica Gets a New Roommate (The Pilot-The Uncut Version)
# Written by: Marta Kauffman & David Crane
#
#
#
#
#  Central Perk, Chandler, Joey, Phoebe, and Monica are there.]
#
# Monica: There's nothing to tell! He's just some guy I work with!
#
# Joey: C'mon, you're going out with the guy! There's gotta be something wrong with him!
#
# Chandler: All right Joey, be nice.  So does he have a hump? A hump and a hairpiece?
#
# Phoebe: Wait, does he eat chalk?
#
# (They all stare, bemused.)
#
# Phoebe: Just, 'cause, I don't want her to go through what I went through with Carl- oh!
#
# Monica: Okay, everybody relax. This is not even a date. It's just two people going out to dinner and- not having sex.
#
# Chandler: Sounds like a date to me.
#
# [Time Lapse]
#
# Chandler: Alright, so I'm back in high school, I'm standing in the middle of the cafeteria, and I realize I am totally naked.
#
# All: Oh, yeah. Had that dream.
#
# ...

# %%
# split episode title 
# to do
episode_title = scenes_of_episode[0]
print(episode_title)
# how do I split it??
# scenes_of_episode_no_title = re.split(episode_title, scenes_of_episode)
# Out:
# The One Where Monica Gets a New Roommate (The Pilot-The Uncut Version)
# Written by: Marta Kauffman & David Crane

# %%
location_list = []
for scene in range(len(scenes_of_episode)):
    location = scenes_of_episode[scene].partition(",")[0]
    location_list.append(location)
    
print(location_list)
# Out:
# ['The One Where Monica Gets a New Roommate (The Pilot-The Uncut Version)\nWritten by: Marta Kauffman & David Crane\n\n\n', ' Central Perk', " Monica's Apartment", ' The Subway', " Ross's Apartment", ' A Restaurant', " Monica's Apartment", " Ross's Apartment; Ross is pacing while Joey and Chandler are working on some more furniture.]\n\nRoss: I'm divorced!  I'm only 26 and I'm divorced!\n\nJoey: Shut up!\n\nChandler: You must stop! (Chandler hits what he is working on with a hammer and it collapses.)\n\nRoss: That only took me an hour.\n\nChandler: Look", ' A Restaurant', " Monica's Apartment", " Ross's Apartment", " Monica's Apartment", ' Iridium', ' Central Perk', " Monica and Rachel's", ' Central Perk']

# %%
# there are some locations that don't get separated with , but with ; 
# so, I had also to delimitter those too.

clean_location_list = []
for location in range(len(location_list)):
    clean_location = location_list[location].partition(';')[0]
    clean_location_list.append(clean_location)
print(clean_location_list)
# Out:
# ['The One Where Monica Gets a New Roommate (The Pilot-The Uncut Version)\nWritten by: Marta Kauffman & David Crane\n\n\n', ' Central Perk', " Monica's Apartment", ' The Subway', " Ross's Apartment", ' A Restaurant', " Monica's Apartment", " Ross's Apartment", ' A Restaurant', " Monica's Apartment", " Ross's Apartment", " Monica's Apartment", ' Iridium', ' Central Perk', " Monica and Rachel's", ' Central Perk']
